# %%
def caesar_encrypt(plaintext_file, ciphertext_file, shift):
    shift = shift % 26  # Ensure shift is within 0-25

    with open(plaintext_file, 'r') as infile:
        plaintext = infile.read()

    ciphertext = ''
    for char in plaintext:
        if char.isalpha():
            base = ord('A') if char.isupper() else ord('a')
            # Shift character
            shifted = (ord(char) - base + shift) % 26 + base
            ciphertext += chr(shifted)
        else:
            ciphertext += char  # Keep non-alphabetic characters unchanged

    with open(ciphertext_file,) as outfile:
        outfile.write(ciphertext)


def caesar_decrypt(ciphertext_file, plaintext_file, shift):
    shift = shift % 26  # Ensure shift is within 0-25

    with open(ciphertext_file, 'r') as infile:
        ciphertext = infile.read()

    plaintext = ''
    for char in ciphertext:
        if char.isalpha():
            base = ord('A') if char.isupper() else ord('a')
            # Reverse shift character
            shifted = (ord(char) - base - shift) % 26 + base
            plaintext += chr(shifted)
        else:
            plaintext += char  # Keep non-alphabetic characters unchanged

    with open(plaintext_file, 'w') as outfile:
        outfile.write(plaintext)

# %%
def caesar_encrypt(plaintext_file, ciphertext_file, shift):
    shift = shift % 26  # Make sure the shift is between 0 and 25

    # Open the file that has the original message
    with open(plaintext_file, 'r') as infile:
        plaintext = infile.read()

    ciphertext = ''  # This will store the hidden message

    # Go through each letter in the message
    for char in plaintext:
        if char.isalpha():  # If it's a letter (A-Z or a-z)
            if char.isupper():
                base = ord('A')  # Starting point for capital letters
            else:
                base = ord('a')  # Starting point for lowercase letters

            # Shift the letter forward
            shifted = (ord(char) - base + shift) % 26 + base
            ciphertext += chr(shifted)  # Add the new letter
        else:
            ciphertext += char  # Keep spaces, punctuation, etc.

    # Save the hidden message to the new file
    with open(ciphertext_file, 'w') as outfile:
        outfile.write(ciphertext)


def caesar_decrypt(ciphertext_file, plaintext_file, shift):
    shift = shift % 26  # Make sure the shift is between 0 and 25

    # Open the file that has the hidden message
    with open(ciphertext_file, 'r') as infile:
        ciphertext = infile.read()

    plaintext = ''  # This will store the original message

    # Go through each letter in the hidden message
    for char in ciphertext:
        if char.isalpha():  # If it's a letter
            if char.isupper():
                base = ord('A')  # Starting point for capital letters
            else:
                base = ord('a')  # Starting point for lowercase letters

            # Shift the letter backward
            shifted = (ord(char) - base - shift) % 26 + base
            plaintext += chr(shifted)  # Add the original letter
        else:
            plaintext += char  # Keep spaces, punctuation, etc.

    # Save the original message to a file
    with open(plaintext_file, 'w') as outfile:
        outfile.write(plaintext)

# %%
def rot13_encrypt(plaintext_file, ciphertext_file):
    def rot13_char(c):
        if c.isalpha():
            base = ord('A') if c.isupper() else ord('a')
            return chr((ord(c) - base + 13) % 26 + base)
        else:
            return c

    with open(plaintext_file, 'r') as fin:
        plaintext = fin.read()

    ciphertext = ''.join(rot13_char(c) for c in plaintext)

    with open(ciphertext_file, 'w') as fout:
        fout.write(ciphertext)


def rot13_decrypt(ciphertext_file, plaintext_file):
    # ROT-13 decryption is same as encryption
    rot13_encrypt(ciphertext_file, plaintext_file)
